# %%
# Importing Libraries
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

# %%
#Opening the url
driver = webdriver.Chrome("chromedriver.exe")
url='https://www.olx.in/'
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : Sedan cars

# %%
search_bar = driver.find_element_by_xpath('//div[@class="zYZEU"]//input')    # Locating search_bar by xpath
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="_3b3oR"]')       # Locating search_button by xpath
search_button.click()

# %%
#defining variables
model_list=[]
year_km_list=[]
location_list=[]
price_list=[]

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):
        price_list.append(j.text)
price_list
# Out:
# ['₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000',
#  '₹ 75,00,000',
#  '₹ 5,45,000',
#  '₹ 18,90,000',
#  '₹ 9,75,000',
#  '₹ 9,80,000',
#  '₹ 9,50,000',
#  '₹ 5,000',
#  '₹ 6,500',
#  '₹ 14,75,000',
#  '₹ 12,75,000',
#  '₹ 5,95,000',
#  '₹ 4,10,000',
#  '₹ 4,57,000',
#  '₹ 12,50,000',
#  '₹ 8,25,000',
#  '₹ 16,00,000',
#  '₹ 19,99,999',
#  '₹ 16,50,000',
#  '₹ 7,90,000',
#  '₹ 8,50,000']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//div[@class="IKo3_"]/span[2]'):
        year_km_list.append(j.text)
year_km_list
# Out:
# ['2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km',
#  '2018 - 25,115 km',
#  '2010 - 120,000 km',
#  '2010 - 61,460 km',
#  '2011 - 52,000 km',
#  '2012 - 90,000 km',
#  '2008 - 81,000 km',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  '2009 - 50,000 km',
#  '2010 - 43,000 km',
#  '2010 - 66,000 km',
#  '2008 - 89,000 km',
#  '2008 - 75,000 km',
#  '2013 - 50,000 km',
#  '2010 - 50,000 km',
#  '2012 - 90,000 km',
#  '2014 - 75,382 km',
#  '2012 - 45,000 km',
#  '2008 - 20,000 km',
#  '2011 - 93,000 km']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_2tW1I"]'):
        model_list.append(j.text)
model_list
# Out:
# ['BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2018, Diesel',
#  'BMW 3 Series 320d Sedan, 2010, Diesel',
#  'BMW 7 Series 730Ld Sedan, 2010, Diesel',
#  'BMW 5 Series 525d Sedan, 2011, Diesel',
#  'BMW 3 Series 320i Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2008, Diesel',
#  'GT spoiler for all sedan cars',
#  'Sedan cars universal spoiler with led piano black',
#  'BMW 7 Series 730Ld Sedan, 2009, Diesel',
#  'BMW 5 Series 523i Sedan, 2010, Petrol',
#  'BMW 5 Series 525i Sedan, 2010, Petrol',
#  'BMW 3 Series 325i Sedan, 2008, Petrol',
#  'BMW 5 Series 523i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2013, Diesel',
#  'BMW 3 Series 320i Sedan, 2010, Petrol',
#  'BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel',
#  'BMW 5 Series 520d Sedan, 2014, Diesel',
#  'BMW 5 Series 530d Highline Sedan, 2012, Diesel',
#  'BMW 5 Series 530i Sedan, 2008, Petrol',
#  'BMW 3 Series 320d Sedan, 2011, Diesel']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="tjgMj"]'):
        location_list.append(j.text)
location_list
# Out:
# ['VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA',
#  'VILE PARLE EAST, MUMBAI',
#  'THANE WEST, THANE',
#  'TATABAD COLONY, COIMBATORE',
#  'KASBA INDUSTRIAL ESTATE, KOLKATA',
#  'SHAKTI NAGAR, AMBALA',
#  'BANDRA WEST, MUMBAI',
#  'KAKKAD, KANNUR',
#  'ERNAKULAM, KOCHI',
#  'SECTOR 15A, CHANDIGARH',
#  'CONNAUGHT PLACE, DELHI',
#  'GULMOHAR ROAD, MUMBAI',
#  'JUBILEE HILLS, HYDERABAD',
#  'PASCHIM VIHAR, DELHI',
#  'GREATER KAILASH, DELHI',
#  'KHARGHAR, NAVI MUMBAI',
#  'VIJAY NAGAR, INDORE',
#  'JANGPURA, DELHI',
#  'GREATER KAILASH 1, DELHI',
#  'VASHI, NAVI MUMBAI',
#  'MAKARPURA, VADODARA']

# %%
print(len(price_list),len(year_km_list),len(model_list),len(location_list))
# Out:
# 1000 1000 1000 1000

# %%
OLX_Sedan=pd.DataFrame({})
OLX_Sedan["location_list"]=location_list[:1000]
OLX_Sedan["model_list"]=model_list[:1000]
OLX_Sedan["year_km_list"]=year_km_list[:1000]
OLX_Sedan["price_list"]=price_list[:1000]
OLX_Sedan[:1000]
# Out:
#                         location_list  \
# 0             VILE PARLE EAST, MUMBAI
# 1                   THANE WEST, THANE
# 2          TATABAD COLONY, COIMBATORE
# 3    KASBA INDUSTRIAL ESTATE, KOLKATA
# 4                SHAKTI NAGAR, AMBALA
# ..                                ...
# 995               VIJAY NAGAR, INDORE
# 996                   JANGPURA, DELHI
# 997          GREATER KAILASH 1, DELHI
# 998                VASHI, NAVI MUMBAI
# 999               MAKARPURA, VADODARA
#
#                                           model_list       year_km_list  \
# 0             BMW 7 Series 730Ld Sedan, 2018, Diesel   2018 - 25,115 km
# 1              BMW 3 Series 320d Sedan, 2010, Diesel  2010 - 120,000 km
# 2             BMW 7 Series 730Ld Sedan, 2010, Diesel   2010 - 61,460 km
# 3              BMW 5 Series 525d Sedan, 2011, Diesel   2011 - 52,000 km
# 4              BMW 3 Series 320i Sedan, 2012, Diesel   2012 - 90,000 km
# ..                                               ...                ...
# 995  BMW 5 Series 2010-2013 520d Sedan, 2012, Diesel   2012 - 90,000 km
# 996            BMW 5 Series 520d Sedan, 2014, Diesel   2014 - 75,382 km
# 997   BMW 5 Series 530d Highline Sedan, 2012, Diesel   2012 - 45,000 km
# 998            BMW 5 Series 530i Sedan, 2008, Petrol   2008 - 20,000 km
# 999            BMW 3 Series 320d Sedan, 2011, Diesel   2011 - 93,000 km
#
#       price_list
# 0    ₹ 75,00,000
# 1     ₹ 5,45,000
# 2    ₹ 18,90,000
# 3     ₹ 9,75,000
# 4     ₹ 9,80,000
# ..           ...
# 995  ₹ 16,00,000
# 996  ₹ 19,99,999
# 997  ₹ 16,50,000
# 998   ₹ 7,90,000
# 999   ₹ 8,50,000
#
# [1000 rows x 4 columns]

# %% [markdown]
# # SUV Cars

# %%
url='https://www.olx.in/'
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : SUV Cars

# %%
search_bar = driver.find_element_by_xpath('//div[@class="zYZEU"]//input')    # Locating search_bar by xpath
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="_3b3oR"]')       # Locating search_button by xpath
search_button.click()

# %%
#defining variables
model_list=[]
year_km_list=[]
location_list=[]
price_list=[]

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):
        price_list.append(j.text)
price_list
# Out:
# ['₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000',
#  '₹ 11,50,000',
#  '₹ 70,00,000',
#  '₹ 21,000',
#  '₹ 4,10,000',
#  '₹ 5,85,000',
#  '₹ 7,51,000',
#  '₹ 75,00,000',
#  '₹ 65,00,000',
#  '₹ 17,00,000',
#  '₹ 2,001',
#  '₹ 1,19,000',
#  '₹ 18,50,000',
#  '₹ 8,50,000',
#  '₹ 8,500',
#  '₹ 3,50,000',
#  '₹ 3,45,000',
#  '₹ 15,25,000',
#  '₹ 5,00,000',
#  '₹ 55,00,000']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//div[@class="IKo3_"]/span[2]'):
        year_km_list.append(j.text)
year_km_list
# Out:
# ['2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km',
#  '2012 - 66,000 km',
#  '2020 - 28,000 km',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  '2005 - 102,625 km',
#  '2015 - 92,500 km',
#  '2018 - 22,000 km',
#  '2007 - 58,000 km',
#  '2010 - 65,000 km',
#  '2018 - 45,000 km',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  '2008 - 160,000 km',
#  '2018 - 49,500 km',
#  '2019 - 11,000 km',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  '2012 - 100,000 km',
#  '2012 - 72,000 km',
#  '2003 - 149,652 km',
#  '2016 - 62,000 km',
#  '2008 - 33,621 km']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_2tW1I"]'):
        model_list.append(j.text)
model_list
# Out:
# ['Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol',
#  'Mitsubishi Pajero Sport 2012 Diesel SUV 4X4',
#  'Hummer H2 SUV, 2020, Petrol',
#  'ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTING FROM 21000 /4',
#  'SUV - Hyundai Tucson 2005 Diesel Well Maintained',
#  'Maruti Suzuki Swift 2015 Diesel 92500 Km Driven',
#  'Ford Ecosport 2018 Diesel 22000 Km Doctor Driven suv',
#  'Hummer H3 SUV, 2007, Petrol',
#  'Hummer H3 SUV, 2010, Petrol',
#  'Hummer H2 SUV, 2018',
#  'All Mitsubishi Car / SUV Parts available Lancer Cedia Outlander Pajero',
#  'Hyundai Verna 2008 CNG & Hybrids 160000 Km Driven super Sedan SUV',
#  'Tucson SUV AT PETROL, Almost New',
#  'FORD ECOSPORT- TITANIUM PETROL SUV LOW KMS ON SALESUV',
#  'Car/SUV bicycle roof rack/carrier (2 bike racks) - Black',
#  'Force motors : Force one Bodytype : SUV Fuel : diesel',
#  'Force one SUV',
#  'Lexus LX 470 SUV, 2003, Diesel',
#  'good condition renualt duster power full car suv 62000 k.m run',
#  'Hummer H3 SUV, 2008, Petrol']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="tjgMj"]'):
        location_list.append(j.text)
location_list
# Out:
# ['WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI',
#  'WORLI, MUMBAI',
#  'ANDHERI WEST, MUMBAI',
#  'CHERANALLOR, KOCHI',
#  'BASAVANAGUDI, BENGALURU',
#  'SOVI GREEN PARK COLONY, RUDRAPUR',
#  'KASHYA ROAD, GORAKHPUR',
#  'MADHAPUR, HYDERABAD',
#  'RAJOURI GARDEN, DELHI',
#  'BEGUMPET, HYDERABAD',
#  'SELAQUI, UTTARANCHAL',
#  'CHENNAI AIR PORT, CHENNAI',
#  'PRAGATI VIHAR, DELHI',
#  'ANSAL PLAZA, GURGAON',
#  'NEW FORT COLONY, BHOPAL',
#  'SRINAGAR, BENGALURU',
#  'JAIL ROAD , NASHIK',
#  'NARODA, AHMEDABAD',
#  'BANJARA HILLS, HYDERABAD',
#  'TANDON BAGICHA, DAMOH',
#  'SANTACRUZ WEST, MUMBAI']

# %%
print(len(price_list),len(year_km_list),len(model_list),len(location_list))
# Out:
# 950 950 950 1000

# %%
OLX_SUV= pd.DataFrame({})
OLX_SUV["location_list"]=location_list[:950]
OLX_SUV["model_list"]=model_list[:950]
OLX_SUV["year_km_list"]=year_km_list[:950]
OLX_SUV["price_list"]=price_list[:950]
OLX_SUV[:950]
# Out:
#                         location_list  \
# 0                       WORLI, MUMBAI
# 1                ANDHERI WEST, MUMBAI
# 2                  CHERANALLOR, KOCHI
# 3             BASAVANAGUDI, BENGALURU
# 4    SOVI GREEN PARK COLONY, RUDRAPUR
# ..                                ...
# 945            KASHYA ROAD, GORAKHPUR
# 946               MADHAPUR, HYDERABAD
# 947             RAJOURI GARDEN, DELHI
# 948               BEGUMPET, HYDERABAD
# 949              SELAQUI, UTTARANCHAL
#
#                                             model_list  \
# 0          Mitsubishi Pajero Sport 2012 Diesel SUV 4X4
# 1                          Hummer H2 SUV, 2020, Petrol
# 2    ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTIN...
# 3     SUV - Hyundai Tucson 2005 Diesel Well Maintained
# 4      Maruti Suzuki Swift 2015 Diesel 92500 Km Driven
# ..                                                 ...
# 945  Force motors : Force one Bodytype : SUV Fuel :...
# 946                                      Force one SUV
# 947                     Lexus LX 470 SUV, 2003, Diesel
# 948  good condition renualt duster power full car s...
# 949                        Hummer H3 SUV, 2008, Petrol
#
#                                           year_km_list   price_list
# 0                                     2012 - 66,000 km  ₹ 11,50,000
# 1                                     2020 - 28,000 km  ₹ 70,00,000
# 2    ALLOY WHEELS FOR ALL CARS & SUV ,PRICE STARTIN...     ₹ 21,000
# 3                                    2005 - 102,625 km   ₹ 4,10,000
# 4                                     2015 - 92,500 km   ₹ 5,85,000
# ..                                                 ...          ...
# 945                                  2012 - 100,000 km   ₹ 3,50,000
# 946                                   2012 - 72,000 km   ₹ 3,45,000
# 947                                  2003 - 149,652 km  ₹ 15,25,000
# 948                                   2016 - 62,000 km   ₹ 5,00,000
# 949                                   2008 - 33,621 km  ₹ 55,00,000
#
# [950 rows x 4 columns]

# %% [markdown]
# # XUV Cars

# %%
url='https://www.olx.in/'
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : XUV cars

# %%
search_bar = driver.find_element_by_xpath('//div[@class="zYZEU"]//input')    # Locating search_bar by xpath
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="_3b3oR"]')       # Locating search_button by xpath
search_button.click()

# %%
#defining variables
model_list=[]
year_km_list=[]
location_list=[]
price_list=[]

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):
        price_list.append(j.text)
price_list
# Out:
# ['₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000',
#  '₹ 16,50,000',
#  '₹ 14,20,000',
#  '₹ 5,25,000',
#  '₹ 9,21,000',
#  '₹ 8,50,000',
#  '₹ 6,00,000',
#  '₹ 4,69,000',
#  '₹ 7,50,000',
#  '₹ 6,20,000',
#  '₹ 3,95,000',
#  '₹ 4,90,000',
#  '₹ 5,75,000',
#  '₹ 7,00,000',
#  '₹ 8,50,000',
#  '₹ 18,00,000',
#  '₹ 8,20,000',
#  '₹ 12,00,000',
#  '₹ 15,50,000',
#  '₹ 5,60,000']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//div[@class="IKo3_"]/span[2]'):
        year_km_list.append(j.text)
year_km_list
# Out:
# ['2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km',
#  '2018 - 81,000 km',
#  '2018 - 67,000 km',
#  '2011 - 83,200 km',
#  '2015 - 112,000 km',
#  '2015 - 95,000 km',
#  '2012 - 130,000 km',
#  '2011 - 120,000 km',
#  '2015 - 92,000 km',
#  '2012 - 120,000 km',
#  '2012 - 120,000 km',
#  '2012 - 79,000 km',
#  '2014 - 55,256 km',
#  '2013 - 178,000 km',
#  '2015 - 14 km',
#  '2021 - 15,000 km',
#  '2014 - 152,000 km',
#  '2016 - 91,000 km',
#  '2019 - 12,865 km',
#  '2013 - 117,145 km']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_2tW1I"]'):
        model_list.append(j.text)
model_list
# Out:
# ['XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013',
#  'XUV 5OO W10 AT',
#  'Xuv 500 W9 black with sunroof , Fixed price.Showroom condition',
#  'Mahindra xuv 500 in very good condition with VIP Number',
#  'XUV 500 XCLUSIVE',
#  'Xuv 500 . 2015 . Well maintained. Single owner. Vip number. Red color',
#  'Mahindra xuv 500',
#  'Mahindra XUV 500 W8',
#  'Mahindra xuv 500 w8',
#  'Xuv 500 w8',
#  'Mahindra XUV',
#  'Mahindra XUV 500 W8 2WD',
#  'Xuv 5002014',
#  '2013 Model XUV 500 W8',
#  'Xuv w 6 top model',
#  'XUV 500/W9/2021-Feb- Excellent condition',
#  'Xuv 500 properly maintained doctor used car',
#  'Well maintained xuv 500 w10',
#  'MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN GREAT CONDITION',
#  'XUV 500 W8 2WD | Diesel | 2013']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="tjgMj"]'):
        location_list.append(j.text)
location_list
# Out:
# ['PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI',
#  'PATTANAMTITTA, PATHANAMTHITTA',
#  'BANGA CHOWK, GARHSHANKAR',
#  'HEBBAL, BENGALURU',
#  'MALAD EAST, MUMBAI',
#  'UPNAGAR, NASHIK',
#  'NAGARJUNA NAGAR COLONY, NASPUR',
#  'KHAMARIA, JABALPUR',
#  'MIRA ROAD EAST, MUMBAI',
#  'CHANDAN NAGAR, INDORE',
#  'SECTOR 1, PANCHKULA',
#  'KHERI, NAKUR',
#  'SHAHEEN BAGH, DELHI',
#  'JEHLITANR, KHELARI',
#  'VAZHAPPILY, MUVATTUPUZHA',
#  'INDUSTRIAL AREA, KORBA',
#  'UPPARPALLY, HYDERABAD',
#  'BRAHMANAMANGALAM, PALLIKONDA',
#  'THAZHAMBUR, CHENNAI',
#  'ATGHARA, KOLKATA',
#  'VASANT VIHAR, DELHI']

# %%
print(len(price_list),len(year_km_list),len(model_list),len(location_list))
# Out:
# 950 950 950 1000

# %%
OLX_XUV= pd.DataFrame({})
OLX_XUV["location_list"]=location_list[:950]
OLX_XUV["model_list"]=model_list[:950]
OLX_XUV["year_km_list"]=year_km_list[:950]
OLX_XUV["price_list"]=price_list[:950]
OLX_XUV[:950]
# Out:
#                       location_list  \
# 0     PATTANAMTITTA, PATHANAMTHITTA
# 1          BANGA CHOWK, GARHSHANKAR
# 2                 HEBBAL, BENGALURU
# 3                MALAD EAST, MUMBAI
# 4                   UPNAGAR, NASHIK
# ..                              ...
# 945  NAGARJUNA NAGAR COLONY, NASPUR
# 946              KHAMARIA, JABALPUR
# 947          MIRA ROAD EAST, MUMBAI
# 948           CHANDAN NAGAR, INDORE
# 949             SECTOR 1, PANCHKULA
#
#                                             model_list       year_km_list  \
# 0                                       XUV 5OO W10 AT   2018 - 81,000 km
# 1    Xuv 500 W9 black with sunroof , Fixed price.Sh...   2018 - 67,000 km
# 2    Mahindra xuv 500 in very good condition with V...   2011 - 83,200 km
# 3                                     XUV 500 XCLUSIVE  2015 - 112,000 km
# 4    Xuv 500 . 2015 . Well maintained. Single owner...   2015 - 95,000 km
# ..                                                 ...                ...
# 945           XUV 500/W9/2021-Feb- Excellent condition   2021 - 15,000 km
# 946        Xuv 500 properly maintained doctor used car  2014 - 152,000 km
# 947                        Well maintained xuv 500 w10   2016 - 91,000 km
# 948  MAHINDRA XUV 500 W11 2019 MT WITH SUNROOF IN G...   2019 - 12,865 km
# 949                     XUV 500 W8 2WD | Diesel | 2013  2013 - 117,145 km
#
#       price_list
# 0    ₹ 16,50,000
# 1    ₹ 14,20,000
# 2     ₹ 5,25,000
# 3     ₹ 9,21,000
# 4     ₹ 8,50,000
# ..           ...
# 945  ₹ 18,00,000
# 946   ₹ 8,20,000
# 947  ₹ 12,00,000
# 948  ₹ 15,50,000
# 949   ₹ 5,60,000
#
# [950 rows x 4 columns]

# %% [markdown]
# # HatchBAck Cars

# %%
url='https://www.olx.in/'
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')


search_bar = driver.find_element_by_xpath('//div[@class="zYZEU"]//input')    # Locating search_bar by xpath
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="_3b3oR"]')       # Locating search_button by xpath
search_button.click()
# Out:
# Enter the product you want to search : Hatchback cars

# %%
#defining variables
model_list=[]
year_km_list=[]
location_list=[]
price_list=[]

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):
        price_list.append(j.text)
price_list
# Out:
# ['₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700',
#  '₹ 2,85,000',
#  '₹ 2,25,000',
#  '₹ 2,65,000',
#  '₹ 2,40,000',
#  '₹ 2,55,000',
#  '₹ 1,90,000',
#  '₹ 1,90,000',
#  '₹ 2,50,000',
#  '₹ 1,00,000',
#  '₹ 4,500',
#  '₹ 1,85,000',
#  '₹ 3,75,000',
#  '₹ 4,25,000',
#  '₹ 2,25,000',
#  '₹ 2,10,000',
#  '₹ 2,700',
#  '₹ 2,700']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//div[@class="IKo3_"]/span[2]'):
        year_km_list.append(j.text)
year_km_list
# Out:
# ['2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  '2015 - 20,600 km',
#  '2014 - 80,000 km',
#  '2015 - 20,000 km',
#  '2013 - 40,000 km',
#  '2014 - 25,375 km',
#  '2013 - 63,000 km',
#  '2013 - 64,000 km',
#  '2010 - 39,718 km',
#  '2010 - 555 km',
#  'Hatchback cars universal wing spoiler',
#  '2014 - 89,000 km',
#  '2016 - 12,000 km',
#  '2016 - 12,000 km',
#  '2014 - 80,000 km',
#  '2013 - 67,000 km',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_2tW1I"]'):
        model_list.append(j.text)
model_list
# Out:
# ['Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback',
#  'Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2015 Petrol',
#  'Chevrolet Sail Hatchback 2012-2013 Petrol, 2013, Petrol',
#  'Chevrolet Sail Hatchback 2014 Petrol 25375 Km Driven',
#  'Chevrolet Sail Hatchback 2012-2013 LS ABS, 2013, CNG & Hybrids',
#  'Chevrolet Sail Hatchback 1.2 LS, 2013, CNG & Hybrids',
#  'Hyundai i20 2010 Petrol 39718 Km Driven Hatchback',
#  'BMW 1 Series 118d Hatchback, 2010',
#  'Hatchback cars universal wing spoiler',
#  'Chevrolet Sail Hatchback 1.3 TCDi, 2014, Diesel',
#  'Chevrolet Sail Hatchback 1.3 TCDi LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol',
#  'Chevrolet Sail Hatchback 1.2, 2014, Petrol',
#  'Chevrolet Sail Hatchback 2013 Petrol Good Condition',
#  '7d mat for all cars suv sedan hatchback',
#  '7d mat for all cars suv sedan hatchback']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="tjgMj"]'):
        location_list.append(j.text)
location_list
# Out:
# ['TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA',
#  'TIMALIAWAD, SURAT',
#  'JAMAN NAGAR, JAIPUR',
#  'PREM NAGAR NEAR CHARIYATOLI, RANCHI',
#  'NARANPURA, AHMEDABAD',
#  'CHOWK BAZAR, TEZPUR',
#  'JANAKPURI, DELHI',
#  'PITAMPURA, DELHI',
#  'CHATERJIHAT, HOWRAH',
#  'VYTTILA, KOCHI',
#  'HAIDERPARA, SILIGURI',
#  'GACHIBOWLI, HYDERABAD',
#  'BIJAPUR RURAL, VIJAYAPURA',
#  'LIC COLONY, BENGALURU',
#  'INDIRA NAGAR, BENGALURU',
#  'SIKAR INDUSTRIAL AREA, SIKAR',
#  'SEAWOODS WEST, NAVI MUMBAI',
#  'ARAKERE, BENGALURU',
#  'MANGLAPURI, DELHI',
#  'RAJIV CHOWK, GURGAON',
#  'BRS NAGAR, LUDHIANA']

# %%
print(len(price_list),len(year_km_list),len(model_list),len(location_list))
# Out:
# 850 850 850 1000

# %%
OLX_HatchBack= pd.DataFrame({})
OLX_HatchBack["location_list"]=location_list[:850]
OLX_HatchBack["model_list"]=model_list[:850]
OLX_HatchBack["year_km_list"]=year_km_list[:850]
OLX_HatchBack["price_list"]=price_list[:850]
OLX_HatchBack[:850]
# Out:
#                            location_list  \
# 0                      TIMALIAWAD, SURAT
# 1                    JAMAN NAGAR, JAIPUR
# 2    PREM NAGAR NEAR CHARIYATOLI, RANCHI
# 3                   NARANPURA, AHMEDABAD
# 4                    CHOWK BAZAR, TEZPUR
# ..                                   ...
# 845                     JANAKPURI, DELHI
# 846                     PITAMPURA, DELHI
# 847                  CHATERJIHAT, HOWRAH
# 848                       VYTTILA, KOCHI
# 849                 HAIDERPARA, SILIGURI
#
#                                             model_list  \
# 0    Chevrolet Sail Hatchback 1.2 LS, 2015, CNG & H...
# 1           Chevrolet Sail Hatchback 1.2, 2014, Petrol
# 2                 Chevrolet Sail Hatchback 2015 Petrol
# 3    Chevrolet Sail Hatchback 2012-2013 Petrol, 201...
# 4    Chevrolet Sail Hatchback 2014 Petrol 25375 Km ...
# ..                                                 ...
# 845  Chevrolet Sail Hatchback 1.2 LS ABS, 2016, Petrol
# 846         Chevrolet Sail Hatchback 1.2, 2014, Petrol
# 847  Chevrolet Sail Hatchback 2013 Petrol Good Cond...
# 848            7d mat for all cars suv sedan hatchback
# 849            7d mat for all cars suv sedan hatchback
#
#                                 year_km_list  price_list
# 0                           2015 - 20,600 km  ₹ 2,85,000
# 1                           2014 - 80,000 km  ₹ 2,25,000
# 2                           2015 - 20,000 km  ₹ 2,65,000
# 3                           2013 - 40,000 km  ₹ 2,40,000
# 4                           2014 - 25,375 km  ₹ 2,55,000
# ..                                       ...         ...
# 845                         2016 - 12,000 km  ₹ 4,25,000
# 846                         2014 - 80,000 km  ₹ 2,25,000
# 847                         2013 - 67,000 km  ₹ 2,10,000
# 848  7d mat for all cars suv sedan hatchback     ₹ 2,700
# 849  7d mat for all cars suv sedan hatchback     ₹ 2,700
#
# [850 rows x 4 columns]

# %% [markdown]
# # Mini Van Cars

# %%
url='https://www.olx.in/'
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')


search_bar = driver.find_element_by_xpath('//div[@class="zYZEU"]//input')    # Locating search_bar by xpath
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="_3b3oR"]')       # Locating search_button by xpath
search_button.click()
# Out:
# Enter the product you want to search : Minivan cars

# %%
#defining variables
model_list=[]
year_km_list=[]
location_list=[]
price_list=[]

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_89yzn"]'):
        price_list.append(j.text)
price_list
# Out:
# ['₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000',
#  '₹ 2,68,999',
#  '₹ 2,45,000',
#  '₹ 90,000',
#  '₹ 3,25,000',
#  '₹ 2,30,000',
#  '₹ 3,25,000',
#  '₹ 2,75,000',
#  '₹ 1,50,000',
#  '₹ 1,90,000',
#  '₹ 1,75,000',
#  '₹ 3,25,000',
#  '₹ 2,82,000',
#  '₹ 2,68,000']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//div[@class="IKo3_"]/span[2]'):
        year_km_list.append(j.text)
year_km_list
# Out:
# ['2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km',
#  '2018 - 60,753 km',
#  '2015 - 61,000 km',
#  '2011 - 20,000 km',
#  'Minivan T board 2017 model single owner',
#  '2011 - 133,000 km',
#  'Maximo minivan 2017 single owner',
#  '2017 - 77,000 km',
#  '2013 - 105,266 km',
#  '2019 - 35,500 km',
#  '2014 - 140,000 km',
#  '2018 - 19,791 km',
#  '2018 - 84,000 km',
#  '2014 - 57,000 km']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="_2tW1I"]'):
        model_list.append(j.text)
model_list
# Out:
# ['Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan',
#  'Mahindra Jeeto minivan good condition',
#  'Good milage Good working maxximo minivan',
#  'Mahendra maxximo minivan',
#  'Minivan T board 2017 model single owner',
#  'Mahindra maxximo minivan',
#  'Maximo minivan 2017 single owner',
#  'Mahindra jeeto minivan',
#  'MAHINDRA MAXXIMO MINIVAN',
#  'Mahindra supro minivan passenger..for sale model 2019..new vehicle..',
#  'Maximum minivan',
#  'Mahindra jeeto minivan pvt',
#  'Mahindra Jeeto minivan 2018',
#  'Maxximo minivan']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="tjgMj"]'):
        location_list.append(j.text)
location_list
# Out:
# ['MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD',
#  'MARADI BASAVESHWAR, BAIL HONGAL',
#  'GAVARAPALEM, ANAKAPALLE',
#  'AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'CHANDRALAYAM, MATTANNUR',
#  'THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI',
#  'PATANI VILLAGE, MARATHAKKARA',
#  'CHHANI JAKAT NAKA, VADODARA',
#  'KOOLIMUTTAM, PAPPINIVATTOM',
#  'BHAIRO GANJ, SEONI',
#  'KARINKARAPPULLI, PALAKKAD',
#  'MANKADA, MALAPPURAM',
#  'PUDUPALLI THERUVU, PALAKKAD']

# %%
print(len(price_list),len(year_km_list),len(model_list),len(location_list))
# Out:
# 650 650 650 650

# %%
OLX_Minivan= pd.DataFrame({})
OLX_Minivan["location_list"]=location_list[:650]
OLX_Minivan["model_list"]=model_list[:650]
OLX_Minivan["year_km_list"]=year_km_list[:650]
OLX_Minivan["price_list"]=price_list[:650]
OLX_Minivan[:650]
# Out:
#                                   location_list  \
# 0               MARADI BASAVESHWAR, BAIL HONGAL
# 1                       GAVARAPALEM, ANAKAPALLE
# 2    AMMAN NAGAR NEAR MACHAMPALAYAM, COIMBATORE
# 3     THEERTHAGIRIYAMPATTU PUDHU NAGAR, CHENNAI
# 4                       CHANDRALAYAM, MATTANNUR
# ..                                          ...
# 645                  KOOLIMUTTAM, PAPPINIVATTOM
# 646                          BHAIRO GANJ, SEONI
# 647                   KARINKARAPPULLI, PALAKKAD
# 648                         MANKADA, MALAPPURAM
# 649                 PUDUPALLI THERUVU, PALAKKAD
#
#                                             model_list  \
# 0                Mahindra Jeeto minivan good condition
# 1             Good milage Good working maxximo minivan
# 2                             Mahendra maxximo minivan
# 3              Minivan T board 2017 model single owner
# 4                             Mahindra maxximo minivan
# ..                                                 ...
# 645  Mahindra supro minivan passenger..for sale mod...
# 646                                    Maximum minivan
# 647                         Mahindra jeeto minivan pvt
# 648                        Mahindra Jeeto minivan 2018
# 649                                    Maxximo minivan
#
#                                 year_km_list  price_list
# 0                           2018 - 60,753 km  ₹ 2,68,999
# 1                           2015 - 61,000 km  ₹ 2,45,000
# 2                           2011 - 20,000 km    ₹ 90,000
# 3    Minivan T board 2017 model single owner  ₹ 3,25,000
# 4                          2011 - 133,000 km  ₹ 2,30,000
# ..                                       ...         ...
# 645                         2019 - 35,500 km  ₹ 1,90,000
# 646                        2014 - 140,000 km  ₹ 1,75,000
# 647                         2018 - 19,791 km  ₹ 3,25,000
# 648                         2018 - 84,000 km  ₹ 2,82,000
# 649                         2014 - 57,000 km  ₹ 2,68,000
#
# [650 rows x 4 columns]

# %% [markdown]
# # Carsdekho

# %%
#Opening the url
driver = webdriver.Chrome("chromedriver.exe")
url='https://www.cardekho.com/'
driver.get(url)

time.sleep(2)

# %%
used_car = driver.find_element_by_xpath("/html/body/div[2]/div/header/div[2]/div/div/nav/ul/li[2]/span/span")
used_car.click()

# %%
#defining variables
model_list=[]
year_km_list=[]
location_list=[]
price_list=[]

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//span[@class="amnt "]'):
        price_list.append(j.text)
price_list
# Out:
# ['2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh',
#  '2.1 Lakh',
#  '7.7 Lakh',
#  '11.5 Lakh',
#  '12 Lakh',
#  '5.25 Lakh',
#  '3.1 Lakh',
#  '6.5 Lakh',
#  '6.5 Lakh',
#  '4.4 Lakh',
#  '8 Lakh',
#  '5.25 Lakh',
#  '5.5 Lakh',
#  '16.8 Lakh',
#  '5.9 Lakh',
#  '3.5 Lakh',
#  '3.45 Lakh',
#  '2.25 Lakh',
#  '3.1 Lakh',
#  '7 Lakh',
#  '7.5 Lakh']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//div[@class="truncate dotlist"]/span[1]'):
        year_km_list.append(j.text)
year_km_list
# Out:
# ['1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  '68,000 kms',
#  '20,000 kms',
#  '42,364 kms',
#  '21,093 kms',
#  '62,126 kms',
#  '17,603 kms',
#  '1,10,890 kms',
#  '50,000 kms',
#  '66,000 kms',
#  '93,534 kms',
#  '21,000 kms',
#  '22,000 kms',
#  '1,28,000 kms',
#  '24,000 kms',
#  '37,000 kms',
#  '34,000 kms',
#  '22,000 kms',
#  '55,000 kms',
#  '1,08,666 kms',
#  '75,000 kms',
#  ...]

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7 carsName"]/a'):
        model_list.append(j.text)
model_list
# Out:
# ['2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V',
#  '2010 Tata Indica Vista',
#  '2018 Maruti Ciaz',
#  '2017 Hyundai Creta',
#  '2014 Toyota Innova',
#  '2017 Hyundai Grand i10',
#  '2010 Ford Figo',
#  '2011 Skoda Superb',
#  '2019 Renault Triber',
#  '2014 Hyundai Grand i10',
#  '2017 Maruti Ciaz',
#  '2019 Maruti Celerio',
#  '2014 Hyundai Xcent',
#  '2016 Toyota Innova Crysta',
#  '2016 Maruti Swift Dzire',
#  '2010 Hyundai i20',
#  '2014 Hyundai EON',
#  '2011 Maruti Alto K10',
#  '2015 Maruti Alto K10',
#  '2018 Maruti Baleno',
#  '2017 Honda WR-V']

# %%
for i in range(0,50):
    for j in driver.find_elements_by_xpath('//div[@class="cityIcon"]'):
        location_list.append(j.text)
location_list
# Out:
# ['Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai']

# %%
print(len(price_list),len(year_km_list),len(model_list),len(location_list))
# Out:
# 1000 1586 1000 1000

# %%
Cardekho= pd.DataFrame({})
Cardekho["location_list"]=location_list[:1000 ]
Cardekho["model_list"]=model_list[:1000 ]
Cardekho["year_km_list"]=year_km_list[:1000 ]
Cardekho["price_list"]=price_list[:1000 ]
Cardekho[:1000 ]
# Out:
#     location_list              model_list  year_km_list price_list
# 0         Chennai  2010 Tata Indica Vista  1,10,890 kms   2.1 Lakh
# 1         Chennai        2018 Maruti Ciaz    50,000 kms   7.7 Lakh
# 2         Chennai      2017 Hyundai Creta    66,000 kms  11.5 Lakh
# 3         Chennai      2014 Toyota Innova    93,534 kms    12 Lakh
# 4         Chennai  2017 Hyundai Grand i10    21,000 kms  5.25 Lakh
# ..            ...                     ...           ...        ...
# 995       Chennai        2014 Hyundai EON    34,000 kms  3.45 Lakh
# 996       Chennai    2011 Maruti Alto K10    22,000 kms  2.25 Lakh
# 997       Chennai    2015 Maruti Alto K10    55,000 kms   3.1 Lakh
# 998       Chennai      2018 Maruti Baleno  1,08,666 kms     7 Lakh
# 999       Chennai         2017 Honda WR-V    75,000 kms   7.5 Lakh
#
# [1000 rows x 4 columns]

# %% [markdown]
# # Concatination

# %%
Cars = pd.concat([OLX_Sedan,OLX_SUV,OLX_XUV,OLX_HatchBack,OLX_Minivan,Cardekho])
Cars
# Out:
#                               location_list  \
# 0    EM BYPASS - SCIENCE CITY AREA, KOLKATA
# 1                      ANDHERI WEST, MUMBAI
# 2                       MAHALAKSHMI, MUMBAI
# 3                       BANDRA WEST, MUMBAI
# 4                            KAKKAD, KANNUR
# ..                                      ...
# 995                                 Chennai
# 996                                 Chennai
# 997                                 Chennai
# 998                                 Chennai
# 999                                 Chennai
#
#                                  model_list                   year_km_list  \
# 0     BMW 5 Series 525i Sedan, 2008, Petrol               2008 - 31,000 km
# 1    BMW 7 Series 740Li Sedan, 2011, Petrol               2011 - 64,000 km
# 2    BMW 7 Series 740Li Sedan, 2011, Petrol               2011 - 64,000 km
# 3     BMW 5 Series 520d Sedan, 2008, Diesel               2008 - 81,000 km
# 4             GT spoiler for all sedan cars  GT spoiler for all sedan cars
# ..                                      ...                            ...
# 995                        2014 Hyundai EON                     34,000 kms
# 996                    2011 Maruti Alto K10                     22,000 kms
# 997                    2015 Maruti Alto K10                     55,000 kms
# 998                      2018 Maruti Baleno                   1,08,666 kms
# 999                         2017 Honda WR-V                     75,000 kms
#
#       price_list
# 0     ₹ 9,50,000
# 1    ₹ 17,50,000
# 2    ₹ 17,50,000
# 3     ₹ 9,50,000
# 4        ₹ 5,000
# ..           ...
# 995    3.45 Lakh
# 996    2.25 Lakh
# 997     3.1 Lakh
# 998       7 Lakh
# 999     7.5 Lakh
#
# [5350 rows x 4 columns]

# %%
Cars.to_excel("Carprice.xlsx")

# %%
Cars.to_csv("Carprice.csv")
